# %%
                                        Practical no : 2
        
        
                    Name : Gauri Chandrakant Bhojane
                    Prn: 2030331245015
                    Subject: Machine Learning
                    Branch: Computer
                    Year: Third(6th sem)
            
            
            
            
                    name of the algorithm : Linear Regression model
                    Dateset: Advertising
                    No of rows: 200
                    No of columns: 400
                    Name of columns: TV, Radio,Newspaper and Sales
                    Mean squared error: 3.9380152204802856
                    Mean absolute percentage error: 0.17222599691973425
                    Accuracy: 99.82777400308026
                        
                        
Model Implementation........

# %%
import numpy as np 
import pandas as pd
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("ML.2.csv")

# %%
dataset.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
dataset.shape
# Out:
# (200, 4)

# %%
dataset.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
x = dataset.iloc[:,:-1].values

# %%
x
# Out:
# array([[230.1,  37.8,  69.2],
#        [ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5],
#        [180.8,  10.8,  58.4],
#        [  8.7,  48.9,  75. ],
#        [ 57.5,  32.8,  23.5],
#        [120.2,  19.6,  11.6],
#        [  8.6,   2.1,   1. ],
#        [199.8,   2.6,  21.2],
#        [ 66.1,   5.8,  24.2],
#        [214.7,  24. ,   4. ],
#        [ 23.8,  35.1,  65.9],
#        [ 97.5,   7.6,   7.2],
#        [204.1,  32.9,  46. ],
#        [195.4,  47.7,  52.9],
#        [ 67.8,  36.6, 114. ],
#        [281.4,  39.6,  55.8],
#        [ 69.2,  20.5,  18.3],
#        [147.3,  23.9,  19.1],
#        [218.4,  27.7,  53.4],
#        [237.4,   5.1,  23.5],
#        [ 13.2,  15.9,  49.6],
#        [228.3,  16.9,  26.2],
#        [ 62.3,  12.6,  18.3],
#        [262.9,   3.5,  19.5],
#        [142.9,  29.3,  12.6],
#        [240.1,  16.7,  22.9],
#        [248.8,  27.1,  22.9],
#        [ 70.6,  16. ,  40.8],
#        [292.9,  28.3,  43.2],
# ...

# %%
 y = dataset.Sales

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
from scipy import stats
dataset_zscore = dataset[(np.abs(stats.zscore(dataset)) < 3).all(axis=1)]

# %%
import pandas as pd

def remove_outliers(dataset,columns,n_std):
    for col in columns:
        print("Working on column: {}".format(col))
        
        mean = dataset[col].mean()
        sd=dataset[col].std()
        
        df = dataset[(dataset[col] <= mean+(n_std*sd))]
        
    return df

# %%
columns = dataset.columns
n_std = 4
dataset_no_outliers = remove_outliers(dataset_zscore,columns,n_std)
# Out:
# Working on column: TV
# Working on column: Radio
# Working on column: Newspaper
# Working on column: Sales

# %%
dataset_no_outliers.shape
# Out:
# (198, 4)

# %%
plt.plot(x,y)
plt.xlabel('TV,Radio and Newspaper')
plt.ylabel('Sales')
plt.title('Advertizing')
plt.show()

# %%
sns.pairplot(dataset,x_vars = ['TV','Radio','Newspaper'],y_vars = 'Sales',kind = 'scatter',diag_kind = None)

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size = 0.70,random_state = 0)

# %%
x_train
# Out:
# array([[265.2,   2.9,  43. ],
#        [197.6,   3.5,   5.9],
#        [218.5,   5.4,  27.4],
#        [147.3,  23.9,  19.1],
#        [171.3,  39.7,  37.7],
#        [217.7,  33.5,  59. ],
#        [262.7,  28.8,  15.9],
#        [163.5,  36.8,   7.4],
#        [100.4,   9.6,   3.6],
#        [ 76.3,  27.5,  16. ],
#        [184.9,  43.9,   1.7],
#        [134.3,   4.9,   9.3],
#        [273.7,  28.9,  59.7],
#        [296.4,  36.3, 100.9],
#        [ 96.2,  14.8,  38.9],
#        [109.8,  47.8,  51.4],
#        [255.4,  26.9,   5.5],
#        [204.1,  32.9,  46. ],
#        [240.1,  16.7,  22.9],
#        [193.7,  35.4,  75.6],
#        [191.1,  28.7,  18.2],
#        [ 89.7,   9.9,  35.7],
#        [ 43. ,  25.9,  20.5],
#        [ 38.2,   3.7,  13.8],
#        [ 13.1,   0.4,  25.6],
#        [239.3,  15.5,  27.3],
#        [ 17.2,  45.9,  69.3],
#        [210.7,  29.5,   9.3],
#        [ 25.6,  39. ,   9.3],
#        [177. ,   9.3,   6.4],
#        [206.9,   8.4,  26.4],
# ...

# %%
y_train
# Out:
# 131    17.7
# 96     16.7
# 181    17.2
# 19     14.6
# 153    16.0
#        ...
# 67     13.4
# 192     5.9
# 117     9.4
# 47     23.2
# 172     7.6
# Name: Sales, Length: 140, dtype: float64

# %%
from sklearn import linear_model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predicted = model.predict(x_test)

# %%
y_predicted
# Out:
# array([10.68909303,  8.67371102,  9.59969914, 24.99989846, 14.73590568,
#         8.37604918, 10.70350416, 18.37670708,  9.9670026 , 17.87946837,
#        23.52765543, 10.70692059, 13.37566958, 17.10051561, 11.77005197,
#        13.31194616, 21.13395461,  9.10945664, 14.24009701, 18.86885012,
#        25.00670623, 12.42508633, 16.61899482, 13.84289673,  7.80458355,
#        15.13012055, 14.69687153, 20.70140682, 16.9844145 ,  8.94984434,
#        12.59168427, 20.93257626, 21.34337227, 21.89151357,  7.23908022,
#         7.06001103,  9.28335812, 15.6840471 , 13.33894748,  7.28903633,
#        11.05676585,  9.08768206, 15.60592891, 18.21716827, 18.9560652 ,
#        13.47385617,  5.36520991, 10.59696871, 15.66036131, 10.98229096,
#        12.20805533, 20.70970272, 20.70533061, 16.95931925,  9.96622132,
#         9.44413497, 23.60505449, 15.99066008, 18.06706692,  8.25675464])

# %%
x_test
# Out:
# array([[ 69.2,  20.5,  18.3],
#        [ 50. ,  11.6,  18.4],
#        [ 90.4,   0.3,  23.2],
#        [289.7,  42.3,  51.2],
#        [170.2,   7.8,  35.2],
#        [ 56.2,   5.7,  29.7],
#        [  8.7,  48.9,  75. ],
#        [240.1,   7.3,   8.7],
#        [ 23.8,  35.1,  65.9],
#        [197.6,  23.3,  14.2],
#        [261.3,  42.7,  54.7],
#        [ 87.2,  11.8,  25.9],
#        [156.6,   2.6,   8.3],
#        [187.8,  21.1,   9.5],
#        [ 76.4,  26.7,  22.3],
#        [120.2,  19.6,  11.6],
#        [265.6,  20. ,   0.3],
#        [  0.7,  39.6,   8.7],
#        [ 74.7,  49.4,  45.7],
#        [213.4,  24.6,  13.1],
#        [287.6,  43. ,  71.8],
#        [140.3,   1.9,   9. ],
#        [175.1,  22.5,  31.5],
#        [131.7,  18.4,  34.6],
#        [ 53.5,   2. ,  21.4],
#        [123.1,  34.6,  12.4],
#        [165.6,  10. ,  17.6],
#        [205. ,  45.1,  19.6],
#        [224. ,   2.4,  15.6],
#        [ 25.1,  25.7,  43.3],
#        [ 67.8,  36.6, 114. ],
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test,y_predicted)

# %%
mse
# Out:
# 3.9380152204802856

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test,y_predicted)

# %%
mape
# Out:
# 0.17222599691973425

# %%
accuracy = 100 - mape

# %%
accuracy
# Out:
# 99.82777400308026
